# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
import gmaps
from config import google_maps_api_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 744

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | behshahr
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | bacolod
# Processing Record 4 of Set 1 | iraucuba
# Processing Record 5 of Set 1 | pevek
# Processing Record 6 of Set 1 | mount isa
# Processing Record 7 of Set 1 | chapleau
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | labutta
# City not found. Skipping
# Processing Record 10 of Set 1 | nome
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | flin flon
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | dakar
# Processing Record 17 of Set 1 | hirara
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | constantine
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | saraland
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | cozumel
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | sao joao do paraiso
# Processing Record 33 of Set 1 | pascagoula
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | vryburg
# Processing Record 37 of Set 1 | tanga
# Processing Record 38 of Set 1 | bonavista
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | bismil
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | szprotawa
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | westport
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | ngukurr
# City not found. Skipping
# Processing Record 49 of Set 1 | jumla
# Processing Record 50 of Set 1 | san jose
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | nanyamba
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | garissa
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | kayerkan
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | calvinia
# Processing Record 17 of Set 2 | keta
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | viedma
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping
# Processing Record 22 of Set 2 | neunkirchen
# Processing Record 23 of Set 2 | tautira
# Processing Record 24 of Set 2 | tungor
# Processing Record 25 of Set 2 | sawtell
# Processing Record 26 of Set 2 | san policarpo
# Processing Record 27 of Set 2 | poum
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 30 of Set 2 | port hedland
# Processing Record 31 of Set 2 | novikovo
# Processing Record 32 of Set 2 | halalo
# City not found. Skipping
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | bajil
# Processing Record 40 of Set 2 | ostersund
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | tanete
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 45 of Set 2 | tala
# Processing Record 46 of Set 2 | herat
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | beidao
# Processing Record 49 of Set 2 | bantry
# Processing Record 50 of Set 2 | kargasok
# Processing Record 1 of Set 3 | sao gabriel da cachoeira
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | aldan
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | korla
# Processing Record 10 of Set 3 | lerwick
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | graciano sanchez
# Processing Record 14 of Set 3 | aykhal
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | berlevag
# Processing Record 17 of Set 3 | sal rei
# Processing Record 18 of Set 3 | belen
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | zabaykalsk
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | milkovo
# Processing Record 25 of Set 3 | burnie
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | kisangani
# Processing Record 28 of Set 3 | praia
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | lewistown
# Processing Record 31 of Set 3 | meadville
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | pokrovsk
# Processing Record 34 of Set 3 | kasra
# City not found. Skipping
# Processing Record 35 of Set 3 | vero beach
# Processing Record 36 of Set 3 | pangoa
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | bargal
# City not found. Skipping
# Processing Record 39 of Set 3 | gamba
# Processing Record 40 of Set 3 | ust-barguzin
# Processing Record 41 of Set 3 | amuntai
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | omboue
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | yining
# Processing Record 3 of Set 4 | zhanakorgan
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | chester
# Processing Record 7 of Set 4 | mazagao
# Processing Record 8 of Set 4 | eureka
# Processing Record 9 of Set 4 | atambua
# Processing Record 10 of Set 4 | komsomolskiy
# Processing Record 11 of Set 4 | aripuana
# Processing Record 12 of Set 4 | wakiso
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | bambanglipuro
# Processing Record 15 of Set 4 | praya
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | nanakuli
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | sabzevar
# Processing Record 20 of Set 4 | rungata
# City not found. Skipping
# Processing Record 21 of Set 4 | manggar
# Processing Record 22 of Set 4 | saint-augustin
# Processing Record 23 of Set 4 | qaqortoq
# Processing Record 24 of Set 4 | kodinar
# Processing Record 25 of Set 4 | skibotn
# Processing Record 26 of Set 4 | satitoa
# City not found. Skipping
# Processing Record 27 of Set 4 | olafsvik
# Processing Record 28 of Set 4 | xanxere
# Processing Record 29 of Set 4 | buin
# Processing Record 30 of Set 4 | rayong
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | kristiinankaupunki
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | langarud
# Processing Record 35 of Set 4 | contamana
# Processing Record 36 of Set 4 | benguela
# Processing Record 37 of Set 4 | cherdyn
# Processing Record 38 of Set 4 | ratnagiri
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | belmonte
# Processing Record 42 of Set 4 | moose factory
# Processing Record 43 of Set 4 | kautokeino
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | padang
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | teya
# Processing Record 48 of Set 4 | huaicheng
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | lamar
# Processing Record 1 of Set 5 | arman
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | drumheller
# Processing Record 5 of Set 5 | carutapera
# Processing Record 6 of Set 5 | torrox
# Processing Record 7 of Set 5 | lolua
# City not found. Skipping
# Processing Record 8 of Set 5 | abu samrah
# Processing Record 9 of Set 5 | dhidhdhoo
# Processing Record 10 of Set 5 | yellowknife
# Processing Record 11 of Set 5 | lokosovo
# Processing Record 12 of Set 5 | los algarrobos
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | vila franca do campo
# Processing Record 16 of Set 5 | nuevo progreso
# Processing Record 17 of Set 5 | tamandare
# Processing Record 18 of Set 5 | bukavu
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | santa cruz cabralia
# Processing Record 21 of Set 5 | vila velha
# Processing Record 22 of Set 5 | mandalgovi
# Processing Record 23 of Set 5 | kirakira
# Processing Record 24 of Set 5 | lakes entrance
# Processing Record 25 of Set 5 | alyangula
# Processing Record 26 of Set 5 | shangrao
# Processing Record 27 of Set 5 | mao
# Processing Record 28 of Set 5 | nouadhibou
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping
# Processing Record 30 of Set 5 | gimli
# Processing Record 31 of Set 5 | namatanai
# Processing Record 32 of Set 5 | yarim
# Processing Record 33 of Set 5 | fare
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | cedar city
# Processing Record 36 of Set 5 | abnub
# Processing Record 37 of Set 5 | ibara
# Processing Record 38 of Set 5 | pocone
# Processing Record 39 of Set 5 | henties bay
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | wahran
# City not found. Skipping
# Processing Record 42 of Set 5 | port hardy
# Processing Record 43 of Set 5 | santo angelo
# Processing Record 44 of Set 5 | galle
# Processing Record 45 of Set 5 | umzimvubu
# City not found. Skipping
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | valparaiso
# Processing Record 48 of Set 5 | ketchikan
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | vyazniki
# Processing Record 2 of Set 6 | samusu
# City not found. Skipping
# Processing Record 3 of Set 6 | bandarbeyla
# Processing Record 4 of Set 6 | sergeyevka
# Processing Record 5 of Set 6 | hovd
# Processing Record 6 of Set 6 | pehowa
# Processing Record 7 of Set 6 | risod
# Processing Record 8 of Set 6 | port hawkesbury
# Processing Record 9 of Set 6 | kutum
# Processing Record 10 of Set 6 | kaina
# Processing Record 11 of Set 6 | avera
# Processing Record 12 of Set 6 | road town
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | bellefontaine
# Processing Record 15 of Set 6 | nakhon phanom
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | savalou
# Processing Record 18 of Set 6 | jardim
# Processing Record 19 of Set 6 | tuatapere
# Processing Record 20 of Set 6 | barra do corda
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping
# Processing Record 22 of Set 6 | qazvin
# Processing Record 23 of Set 6 | buala
# Processing Record 24 of Set 6 | samana
# Processing Record 25 of Set 6 | kashi
# Processing Record 26 of Set 6 | dongning
# Processing Record 27 of Set 6 | pandan
# Processing Record 28 of Set 6 | ardistan
# City not found. Skipping
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | jiaozuo
# Processing Record 31 of Set 6 | areia branca
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | hami
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping
# Processing Record 37 of Set 6 | upernavik
# Processing Record 38 of Set 6 | carupano
# Processing Record 39 of Set 6 | griffith
# Processing Record 40 of Set 6 | bethel
# Processing Record 41 of Set 6 | dunedin
# Processing Record 42 of Set 6 | babanusah
# City not found. Skipping
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | rominimbang
# Processing Record 46 of Set 6 | agdas
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | zeya
# Processing Record 49 of Set 6 | rawannawi
# City not found. Skipping
# Processing Record 50 of Set 6 | rocha
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | lashio
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | chicama
# Processing Record 5 of Set 7 | buraydah
# Processing Record 6 of Set 7 | kyshtovka
# Processing Record 7 of Set 7 | paraiso
# Processing Record 8 of Set 7 | pemangkat
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | zachagansk
# City not found. Skipping
# Processing Record 11 of Set 7 | thinadhoo
# Processing Record 12 of Set 7 | asfi
# Processing Record 13 of Set 7 | port-gentil
# Processing Record 14 of Set 7 | muromtsevo
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | giyani
# Processing Record 17 of Set 7 | puerto cortes
# City not found. Skipping
# Processing Record 18 of Set 7 | zhoucheng
# Processing Record 19 of Set 7 | vanimo
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | porto nacional
# Processing Record 22 of Set 7 | morro bay
# Processing Record 23 of Set 7 | inverell
# Processing Record 24 of Set 7 | monrovia
# Processing Record 25 of Set 7 | ushtobe
# Processing Record 26 of Set 7 | mayor pablo lagerenza
# Processing Record 27 of Set 7 | erenhot
# Processing Record 28 of Set 7 | asau
# Processing Record 29 of Set 7 | sambava
# Processing Record 30 of Set 7 | sinop
# Processing Record 31 of Set 7 | nizwa
# Processing Record 32 of Set 7 | bathsheba
# Processing Record 33 of Set 7 | louisbourg
# City not found. Skipping
# Processing Record 34 of Set 7 | saint anthony
# Processing Record 35 of Set 7 | skibbereen
# Processing Record 36 of Set 7 | havoysund
# Processing Record 37 of Set 7 | verkh-usugli
# Processing Record 38 of Set 7 | neryungri
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | ghanzi
# Processing Record 41 of Set 7 | medea
# Processing Record 42 of Set 7 | puli
# Processing Record 43 of Set 7 | khromtau
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | namwala
# Processing Record 46 of Set 7 | port elizabeth
# Processing Record 47 of Set 7 | colonia
# Processing Record 48 of Set 7 | robertsport
# Processing Record 49 of Set 7 | buenos aires
# Processing Record 50 of Set 7 | tarudant
# City not found. Skipping
# Processing Record 1 of Set 8 | daru
# Processing Record 2 of Set 8 | borskoye
# Processing Record 3 of Set 8 | udachnyy
# Processing Record 4 of Set 8 | vila do maio
# Processing Record 5 of Set 8 | christchurch
# Processing Record 6 of Set 8 | byron bay
# Processing Record 7 of Set 8 | damaturu
# Processing Record 8 of Set 8 | outjo
# Processing Record 9 of Set 8 | churapcha
# Processing Record 10 of Set 8 | acuna
# City not found. Skipping
# Processing Record 11 of Set 8 | imbituba
# Processing Record 12 of Set 8 | chumikan
# Processing Record 13 of Set 8 | russell
# Processing Record 14 of Set 8 | bhavani
# Processing Record 15 of Set 8 | lavrentiya
# Processing Record 16 of Set 8 | moorpark
# Processing Record 17 of Set 8 | namibe
# Processing Record 18 of Set 8 | veraval
# Processing Record 19 of Set 8 | saint-georges
# Processing Record 20 of Set 8 | nacala
# Processing Record 21 of Set 8 | leh
# Processing Record 22 of Set 8 | karaul
# City not found. Skipping
# Processing Record 23 of Set 8 | inhambane
# Processing Record 24 of Set 8 | cravo norte
# Processing Record 25 of Set 8 | pangai
# Processing Record 26 of Set 8 | nanortalik
# Processing Record 27 of Set 8 | mahon
# Processing Record 28 of Set 8 | trelew
# Processing Record 29 of Set 8 | jiblah
# Processing Record 30 of Set 8 | basco
# Processing Record 31 of Set 8 | shelburne
# Processing Record 32 of Set 8 | abu kamal
# Processing Record 33 of Set 8 | svetlaya
# Processing Record 34 of Set 8 | dongsheng
# Processing Record 35 of Set 8 | ksenyevka
# City not found. Skipping
# Processing Record 36 of Set 8 | nizhniy kuranakh
# Processing Record 37 of Set 8 | san andres
# Processing Record 38 of Set 8 | campo grande
# Processing Record 39 of Set 8 | daxian
# City not found. Skipping
# Processing Record 40 of Set 8 | uribia
# Processing Record 41 of Set 8 | luderitz
# Processing Record 42 of Set 8 | attawapiskat
# City not found. Skipping
# Processing Record 43 of Set 8 | sungurlu
# Processing Record 44 of Set 8 | anadyr
# Processing Record 45 of Set 8 | merauke
# Processing Record 46 of Set 8 | marzuq
# Processing Record 47 of Set 8 | sakata
# Processing Record 48 of Set 8 | nisia floresta
# Processing Record 49 of Set 8 | los llanos de aridane
# Processing Record 50 of Set 8 | ahipara
# Processing Record 1 of Set 9 | ust-kamchatsk
# City not found. Skipping
# Processing Record 2 of Set 9 | naze
# Processing Record 3 of Set 9 | taiyuan
# Processing Record 4 of Set 9 | riyadh
# Processing Record 5 of Set 9 | dolbeau
# City not found. Skipping
# Processing Record 6 of Set 9 | taoudenni
# Processing Record 7 of Set 9 | santa marta
# Processing Record 8 of Set 9 | ambilobe
# Processing Record 9 of Set 9 | lafia
# Processing Record 10 of Set 9 | sinnamary
# Processing Record 11 of Set 9 | roald
# Processing Record 12 of Set 9 | cordoba
# Processing Record 13 of Set 9 | vila
# Processing Record 14 of Set 9 | launceston
# Processing Record 15 of Set 9 | dodge city
# Processing Record 16 of Set 9 | mount gambier
# Processing Record 17 of Set 9 | tabiauea
# City not found. Skipping
# Processing Record 18 of Set 9 | mahebourg
# Processing Record 19 of Set 9 | namuac
# Processing Record 20 of Set 9 | mapiripan
# Processing Record 21 of Set 9 | oyem
# Processing Record 22 of Set 9 | morant bay
# Processing Record 23 of Set 9 | kaeo
# Processing Record 24 of Set 9 | port blair
# Processing Record 25 of Set 9 | tazovskiy
# Processing Record 26 of Set 9 | lucea
# Processing Record 27 of Set 9 | rabo de peixe
# Processing Record 28 of Set 9 | remiremont
# Processing Record 29 of Set 9 | meulaboh
# Processing Record 30 of Set 9 | dongzhen
# Processing Record 31 of Set 9 | yumen
# Processing Record 32 of Set 9 | yambio
# Processing Record 33 of Set 9 | celarevo
# Processing Record 34 of Set 9 | vengerovo
# Processing Record 35 of Set 9 | nguiu
# City not found. Skipping
# Processing Record 36 of Set 9 | sterling
# Processing Record 37 of Set 9 | kozhva
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | arak
# Processing Record 40 of Set 9 | fort collins
# Processing Record 41 of Set 9 | angoram
# Processing Record 42 of Set 9 | mackay
# Processing Record 43 of Set 9 | fortuna
# Processing Record 44 of Set 9 | sault sainte marie
# Processing Record 45 of Set 9 | utiroa
# City not found. Skipping
# Processing Record 46 of Set 9 | copiapo
# Processing Record 47 of Set 9 | yulara
# Processing Record 48 of Set 9 | kijang
# Processing Record 49 of Set 9 | kalakamati
# Processing Record 50 of Set 9 | shimoda
# Processing Record 1 of Set 10 | shadrinsk
# Processing Record 2 of Set 10 | barawe
# City not found. Skipping
# Processing Record 3 of Set 10 | tooele
# Processing Record 4 of Set 10 | kavaratti
# Processing Record 5 of Set 10 | whittlesea
# Processing Record 6 of Set 10 | the valley
# Processing Record 7 of Set 10 | olinda
# Processing Record 8 of Set 10 | cayenne
# Processing Record 9 of Set 10 | coronado
# Processing Record 10 of Set 10 | zhuhai
# Processing Record 11 of Set 10 | scarborough
# Processing Record 12 of Set 10 | mabaruma
# Processing Record 13 of Set 10 | antofagasta
# Processing Record 14 of Set 10 | pacific grove
# Processing Record 15 of Set 10 | san juan
# Processing Record 16 of Set 10 | chaupimarca
# Processing Record 17 of Set 10 | ishigaki
# Processing Record 18 of Set 10 | aluksne
# Processing Record 19 of Set 10 | coihaique
# Processing Record 20 of Set 10 | carroll
# Processing Record 21 of Set 10 | challapata
# Processing Record 22 of Set 10 | virginia beach
# Processing Record 23 of Set 10 | goshen
# Processing Record 24 of Set 10 | healesville
# Processing Record 25 of Set 10 | mongo
# Processing Record 26 of Set 10 | batemans bay
# Processing Record 27 of Set 10 | tiarei
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | alta floresta
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | saint-joseph
# Processing Record 32 of Set 10 | nyurba
# Processing Record 33 of Set 10 | hanzhong
# Processing Record 34 of Set 10 | meadow lake
# Processing Record 35 of Set 10 | alghero
# Processing Record 36 of Set 10 | tete
# Processing Record 37 of Set 10 | northam
# Processing Record 38 of Set 10 | cabedelo
# Processing Record 39 of Set 10 | tall kayf
# Processing Record 40 of Set 10 | abapo
# Processing Record 41 of Set 10 | bocanda
# Processing Record 42 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 10 | barra patuca
# Processing Record 44 of Set 10 | asaba
# Processing Record 45 of Set 10 | san quintin
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | maridi
# Processing Record 48 of Set 10 | frontera
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 1 of Set 11 | ziro
# Processing Record 2 of Set 11 | barinas
# Processing Record 3 of Set 11 | trinidad
# Processing Record 4 of Set 11 | ulladulla
# Processing Record 5 of Set 11 | chunoyar
# Processing Record 6 of Set 11 | tigil
# Processing Record 7 of Set 11 | biak
# Processing Record 8 of Set 11 | sobolevo
# Processing Record 9 of Set 11 | tubinskiy
# Processing Record 10 of Set 11 | marrakesh
# Processing Record 11 of Set 11 | lagoa
# Processing Record 12 of Set 11 | sehithwa
# Processing Record 13 of Set 11 | namtsy
# Processing Record 14 of Set 11 | aklavik
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | stromness
# Processing Record 17 of Set 11 | cascais
# Processing Record 18 of Set 11 | simao
# Processing Record 19 of Set 11 | kilindoni
# Processing Record 20 of Set 11 | la ronge
# Processing Record 21 of Set 11 | shingu
# Processing Record 22 of Set 11 | valdivia
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | pitimbu
# Processing Record 25 of Set 11 | keningau
# Processing Record 26 of Set 11 | davila
# Processing Record 27 of Set 11 | iberia
# Processing Record 28 of Set 11 | lhuntshi
# City not found. Skipping
# Processing Record 29 of Set 11 | taltal
# Processing Record 30 of Set 11 | tiznit
# Processing Record 31 of Set 11 | pacifica
# Processing Record 32 of Set 11 | kenora
# Processing Record 33 of Set 11 | lufilufi
# Processing Record 34 of Set 11 | montecristo
# Processing Record 35 of Set 11 | qasigiannguit
# Processing Record 36 of Set 11 | san angelo
# Processing Record 37 of Set 11 | carikar
# City not found. Skipping
# Processing Record 38 of Set 11 | antalaha
# Processing Record 39 of Set 11 | alofi
# Processing Record 40 of Set 11 | rodos
# Processing Record 41 of Set 11 | ndjole
# Processing Record 42 of Set 11 | buqayq
# City not found. Skipping
# Processing Record 43 of Set 11 | toledo
# Processing Record 44 of Set 11 | cervo
# Processing Record 45 of Set 11 | rabaul
# Processing Record 46 of Set 11 | port lincoln
# Processing Record 47 of Set 11 | vanavara
# Processing Record 48 of Set 11 | sakakah
# Processing Record 49 of Set 11 | kaduqli
# Processing Record 50 of Set 11 | birao
# Processing Record 1 of Set 12 | kamenskoye
# City not found. Skipping
# Processing Record 2 of Set 12 | hualmay
# Processing Record 3 of Set 12 | quetzaltepec
# City not found. Skipping
# Processing Record 4 of Set 12 | kotri
# Processing Record 5 of Set 12 | prince rupert
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | rio gallegos
# Processing Record 8 of Set 12 | charters towers
# Processing Record 9 of Set 12 | zhongshu
# Processing Record 10 of Set 12 | channel-port aux basques
# Processing Record 11 of Set 12 | fenoarivo atsinanana
# Processing Record 12 of Set 12 | pisco
# Processing Record 13 of Set 12 | banda aceh
# Processing Record 14 of Set 12 | tarko-sale
# Processing Record 15 of Set 12 | alotau
# City not found. Skipping
# Processing Record 16 of Set 12 | mchinji
# Processing Record 17 of Set 12 | makat
# Processing Record 18 of Set 12 | sisimiut
# Processing Record 19 of Set 12 | banjar
# Processing Record 20 of Set 12 | necochea
# Processing Record 21 of Set 12 | borogontsy
# Processing Record 22 of Set 12 | marcona
# City not found. Skipping
# Processing Record 23 of Set 12 | la primavera
# Processing Record 24 of Set 12 | capreol
# Processing Record 25 of Set 12 | alice springs
# Processing Record 26 of Set 12 | gdov
# Processing Record 27 of Set 12 | boguchany
# Processing Record 28 of Set 12 | honiara
# Processing Record 29 of Set 12 | santa cruz del norte
# Processing Record 30 of Set 12 | omsukchan
# Processing Record 31 of Set 12 | krasnaya gorbatka
# Processing Record 32 of Set 12 | kurumkan
# Processing Record 33 of Set 12 | parkes
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | tawau
# Processing Record 36 of Set 12 | kazalinsk
# City not found. Skipping
# Processing Record 37 of Set 12 | koscian
# Processing Record 38 of Set 12 | athabasca
# Processing Record 39 of Set 12 | bubaque
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | aporawan
# City not found. Skipping
# Processing Record 42 of Set 12 | mandurah
# Processing Record 43 of Set 12 | half moon bay
# Processing Record 44 of Set 12 | okhotsk
# Processing Record 45 of Set 12 | huarmey
# Processing Record 46 of Set 12 | andenes
# Processing Record 47 of Set 12 | melito di porto salvo
# Processing Record 48 of Set 12 | tessalit
# Processing Record 49 of Set 12 | akyab
# Processing Record 50 of Set 12 | ruatoria
# City not found. Skipping
# Processing Record 1 of Set 13 | pangnirtung
# Processing Record 2 of Set 13 | toftir
# City not found. Skipping
# Processing Record 3 of Set 13 | hit
# Processing Record 4 of Set 13 | mayo
# Processing Record 5 of Set 13 | khormuj
# City not found. Skipping
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | kuopio
# Processing Record 8 of Set 13 | helena
# Processing Record 9 of Set 13 | el limon
# Processing Record 10 of Set 13 | yatou
# Processing Record 11 of Set 13 | faya
# Processing Record 12 of Set 13 | zheleznodorozhnyy
# Processing Record 13 of Set 13 | fairview
# Processing Record 14 of Set 13 | angoche
# Processing Record 15 of Set 13 | gold coast
# Processing Record 16 of Set 13 | ambon
# Processing Record 17 of Set 13 | sao joao da barra
# Processing Record 18 of Set 13 | qeshm
# Processing Record 19 of Set 13 | sao miguel
# Processing Record 20 of Set 13 | isangel
# Processing Record 21 of Set 13 | newark
# Processing Record 22 of Set 13 | cao bang
# Processing Record 23 of Set 13 | santiago
# Processing Record 24 of Set 13 | hearst
# Processing Record 25 of Set 13 | teguise
# Processing Record 26 of Set 13 | kungurtug
# Processing Record 27 of Set 13 | riwaka
# Processing Record 28 of Set 13 | paciran
# Processing Record 29 of Set 13 | whitehorse
# Processing Record 30 of Set 13 | slovenska bistrica
# Processing Record 31 of Set 13 | vestmanna
# Processing Record 32 of Set 13 | oriximina
# Processing Record 33 of Set 13 | garden city
# Processing Record 34 of Set 13 | ust-nera
# Processing Record 35 of Set 13 | saldanha
# Processing Record 36 of Set 13 | moyale
# Processing Record 37 of Set 13 | panzhihua
# Processing Record 38 of Set 13 | libenge
# Processing Record 39 of Set 13 | baghdad
# Processing Record 40 of Set 13 | nalut
# Processing Record 41 of Set 13 | jeremoabo
# Processing Record 42 of Set 13 | alekseyevka
# Processing Record 43 of Set 13 | metro
# Processing Record 44 of Set 13 | baker city
# Processing Record 45 of Set 13 | bolshoy uluy
# City not found. Skipping
# Processing Record 46 of Set 13 | gus-khrustalnyy
# Processing Record 47 of Set 13 | paamiut
# Processing Record 48 of Set 13 | sibolga
# Processing Record 49 of Set 13 | sabha
# Processing Record 50 of Set 13 | san vicente de canete
# Processing Record 1 of Set 14 | itoman
# Processing Record 2 of Set 14 | grand-lahou
# Processing Record 3 of Set 14 | dutse
# Processing Record 4 of Set 14 | funadhoo
# Processing Record 5 of Set 14 | yangambi
# Processing Record 6 of Set 14 | agirish
# Processing Record 7 of Set 14 | oussouye
# Processing Record 8 of Set 14 | mandal
# Processing Record 9 of Set 14 | kansanshi
# Processing Record 10 of Set 14 | cloquet
# Processing Record 11 of Set 14 | olga
# Processing Record 12 of Set 14 | oistins
# Processing Record 13 of Set 14 | oksfjord
# Processing Record 14 of Set 14 | umm lajj
# Processing Record 15 of Set 14 | sakti
# Processing Record 16 of Set 14 | show low
# Processing Record 17 of Set 14 | jiayuguan
# Processing Record 18 of Set 14 | yabelo
# Processing Record 19 of Set 14 | maputo
# Processing Record 20 of Set 14 | rambha
# Processing Record 21 of Set 14 | varhaug
# Processing Record 22 of Set 14 | maniitsoq
# Processing Record 23 of Set 14 | crab hill
# City not found. Skipping
# Processing Record 24 of Set 14 | gumdag
# Processing Record 25 of Set 14 | carros
# Processing Record 26 of Set 14 | bukene
# Processing Record 27 of Set 14 | sao felix do xingu
# Processing Record 28 of Set 14 | ijaki
# City not found. Skipping
# Processing Record 29 of Set 14 | samarai
# Processing Record 30 of Set 14 | wasilla
# Processing Record 31 of Set 14 | nouakchott
# Processing Record 32 of Set 14 | presidencia roque saenz pena
# Processing Record 33 of Set 14 | burica
# City not found. Skipping
# Processing Record 34 of Set 14 | altamont
# Processing Record 35 of Set 14 | lai
# Processing Record 36 of Set 14 | seydi
# Processing Record 37 of Set 14 | makakilo city
# Processing Record 38 of Set 14 | gazanjyk
# Processing Record 39 of Set 14 | bridlington
# Processing Record 40 of Set 14 | chara
# Processing Record 41 of Set 14 | angra
# City not found. Skipping
# Processing Record 42 of Set 14 | oga
# Processing Record 43 of Set 14 | lindon
# Processing Record 44 of Set 14 | cosamaloapan
# Processing Record 45 of Set 14 | plainview
# Processing Record 46 of Set 14 | dibaya
# City not found. Skipping
# Processing Record 47 of Set 14 | maniwaki
# Processing Record 48 of Set 14 | gat
# Processing Record 49 of Set 14 | jibuti
# Processing Record 50 of Set 14 | xiaoweizhai
# Processing Record 1 of Set 15 | gawler
# Processing Record 2 of Set 15 | lingao
# Processing Record 3 of Set 15 | luang prabang
# Processing Record 4 of Set 15 | provost
# Processing Record 5 of Set 15 | sembe
# Processing Record 6 of Set 15 | rawson
# Processing Record 7 of Set 15 | college
# Processing Record 8 of Set 15 | koping
# Processing Record 9 of Set 15 | sur
# Processing Record 10 of Set 15 | gorin
# Processing Record 11 of Set 15 | swift current
# Processing Record 12 of Set 15 | copala
# Processing Record 13 of Set 15 | blagoveshchenka
# Processing Record 14 of Set 15 | atar
# Processing Record 15 of Set 15 | nicoya
# Processing Record 16 of Set 15 | nizhniy tsasuchey
# Processing Record 17 of Set 15 | quatre cocos
# Processing Record 18 of Set 15 | adrar
# Processing Record 19 of Set 15 | altamira
# Processing Record 20 of Set 15 | hagere selam
# Processing Record 21 of Set 15 | deloraine
# Processing Record 22 of Set 15 | tumannyy
# City not found. Skipping
# Processing Record 23 of Set 15 | neiafu
# Processing Record 24 of Set 15 | vagur
# Processing Record 25 of Set 15 | salinopolis
# Processing Record 26 of Set 15 | antalya
# Processing Record 27 of Set 15 | gizo
# Processing Record 28 of Set 15 | san luis
# Processing Record 29 of Set 15 | niltepec
# Processing Record 30 of Set 15 | chapais
# Processing Record 31 of Set 15 | po
# City not found. Skipping
# Processing Record 32 of Set 15 | bikaner
# Processing Record 33 of Set 15 | pokhara
# Processing Record 34 of Set 15 | otofuke
# Processing Record 35 of Set 15 | hakvik
# City not found. Skipping
# Processing Record 36 of Set 15 | zhangye
# Processing Record 37 of Set 15 | rapar
# Processing Record 38 of Set 15 | labuhan
# Processing Record 39 of Set 15 | richmond
# Processing Record 40 of Set 15 | tynda
# Processing Record 41 of Set 15 | yialos
# City not found. Skipping
# Processing Record 42 of Set 15 | wai
# Processing Record 43 of Set 15 | bellegarde-sur-valserine
# Processing Record 44 of Set 15 | zhigalovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Behshahr      IR  36.6923   53.5526     56.21        82          36
# 1      Kapaa      US  22.0752 -159.3190     74.48        93          75
# 2    Bacolod      PH  10.6667  122.9500     74.32        96         100
# 3   Iraucuba      BR  -3.7461  -39.7833     81.39        81          96
# 4      Pevek      RU  69.7008  170.3133    -21.53       100          87
# 5  Mount Isa      AU -20.7333  139.5000     85.77        28          71
# 6   Chapleau      CA  47.8405  -83.4034     41.09        38          40
# 7  Ostrovnoy      RU  68.0531   39.5131     34.56        98         100
# 8       Nome      US  64.5011 -165.4064     28.47        93         100
# 9   Hermanus      ZA -34.4187   19.2345     66.79        78           1
#
#    Wind Speed   Current Description
# 0        5.14      scattered clouds
# 1       17.27         broken clouds
# 2        5.75  heavy intensity rain
# 3        3.47       overcast clouds
# 4        3.36       overcast clouds
# 5        8.05         broken clouds
# 6        3.44      scattered clouds
# 7       15.73            light snow
# 8       13.80       overcast clouds
# 9       10.36             clear sky

# %%
# Create CSV file of DF
csv_weather_file = "/Users/bkieh/Desktop/School/Classwork/Python/Python_APIs/WeatherPy_Analysis/Weather_Database/weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
